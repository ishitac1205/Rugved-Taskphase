# %%
import pandas as pd

# %%
df=pd.read_csv('pokemon_data.csv')

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df['Legendary'][90:57:-1])
# Out:
# 90    False
# 89    False
# 88    False
# 87    False
# 86    False
# 85    False
# 84    False
# 83    False
# 82    False
# 81    False
# 80    False
# 79    False
# 78    False
# 77    False
# 76    False
# 75    False
# 74    False
# 73    False
# 72    False
# 71    False
# 70    False
# 69    False
# 68    False
# 67    False
# 66    False
# 65    False
# 64    False
# 63    False
# 62    False
# 61    False
# 60    False
# 59    False
# 58    False
# Name: Legendary, dtype: bool

# %%
df.iloc[8]
# Out:
# #                                     6
# Name          CharizardMega Charizard Y
# Type 1                             Fire
# Type 2                           Flying
# HP                                   78
# Attack                              104
# Defense                              78
# Sp. Atk                             159
# Sp. Def                             115
# Speed                               100
# Generation                            1
# Legendary                         False
# Name: 8, dtype: object

# %%
print(df.iloc[0:9])
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
print(df.iloc[0,1])
# Out:
# Bulbasaur

# %%
for index,row in df.iterrows():
    print(index,row[1:5])
    if index==6:
        break
# Out:
# 0 Name      Bulbasaur
# Type 1        Grass
# Type 2       Poison
# HP               45
# Name: 0, dtype: object
# 1 Name      Ivysaur
# Type 1      Grass
# Type 2     Poison
# HP             60
# Name: 1, dtype: object
# 2 Name      Venusaur
# Type 1       Grass
# Type 2      Poison
# HP              80
# Name: 2, dtype: object
# 3 Name      VenusaurMega Venusaur
# Type 1                    Grass
# Type 2                   Poison
# HP                           80
# Name: 3, dtype: object
# 4 Name      Charmander
# Type 1          Fire
# Type 2           NaN
# HP                39
# Name: 4, dtype: object
# 5 Name      Charmeleon
# Type 1          Fire
# Type 2           NaN
# HP                58
# Name: 5, dtype: object
# 6 Name      Charizard
# Type 1         Fire
# Type 2       Flying
# HP               78
# Name: 6, dtype: object

# %%
df.loc[df['Type 1']=="Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Type 1', ascending=False)
# Out:
#        #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 371  339  Barboach  Water  Ground  50      48       43       46       41
# 97    90  Shellder  Water     NaN  30      65      100       45       25
# 240  222   Corsola  Water    Rock  55      55       85       65       85
# 403  368  Gorebyss  Water     NaN  55      84      105      114       75
# 93    86      Seel  Water     NaN  65      45       55       45       70
# ..   ...       ...    ...     ...  ..     ...      ...      ...      ...
# 54    49  Venomoth    Bug  Poison  70      65       60       90       75
# 208  193     Yanma    Bug  Flying  65      65       45       75       45
# 182  168   Ariados    Bug  Poison  70      90       70       60       60
# 734  666  Vivillon    Bug  Flying  80      52       50       90       50
# 179  165    Ledyba    Bug  Flying  40      20       30       40       80
#
#      Speed  Generation  Legendary
# 371     60           3      False
# ...

# %%
df.sort_values(['#','Attack'],ascending=[0,1])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 799  721              Volcanion     Fire   Water  80     110      120
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# ..   ...                    ...      ...     ...  ..     ...      ...
# 4      4             Charmander     Fire     NaN  39      52       43
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 0      1              Bulbasaur    Grass  Poison  45      49       49
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 799      130       90     70           6       True
# ...

# %%
df['t_stat']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  t_stat
# 0         65       65     45           1      False     318
# ...

# %%
45+49+49+65+65+45
# Out:
# 318

# %%
df['t_stat2']=df.iloc[:,4:10].sum(axis=1)

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  t_stat  t_stat2
# ...

# %%
df=df.drop(columns='t_stat2')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  t_stat
# 0         65       65     45           1      False     318
# ...

# %%
col_list=list(df.columns)
print(col_list)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 't_stat']

# %%
df=df[col_list[0:10]+[col_list[-1]]+col_list[10:12]]

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  t_stat  Generation  Legendary
# 0         65       65     45     318           1      False
# ...

# %%
df.to_csv('new_poke.txt',index=False,sep='\t')

# %%
df.to_csv('new_poke.csv',index=False)

# %%
new_df=df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') & (df['Sp. Def']>50)]

# %%
new_df.to_csv('poke_part.csv')

# %%
print(new_df)
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# 451  406                  Budew  Grass  Poison   40      30       35       50
# 452  407               Roserade  Grass  Poison   60      70       65      125
# ...

# %%
new_df.reset_index(drop=True, inplace=True)

# %%
new_df.loc[(new_df['Generation']>=0)]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, t_stat, Generation, Legendary]
# Index: []

# %%
df.loc[~(df['Name'].str.contains('Mega'))]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
df.loc[df['Name'].str.contains('pi[a-z]*',regex=True)]
# Out:
#        #        Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 13    10    Caterpie      Bug     NaN   45      30       35       20       20
# 42    37      Vulpix     Fire     NaN   38      41       40       50       65
# 76    70  Weepinbell    Grass  Poison   65      90       50       85       45
# 84    78    Rapidash     Fire     NaN   65     100       70       80       80
# 181  167    Spinarak      Bug  Poison   40      60       40       40       40
# 189  175      Togepi    Fairy     NaN   35      20       65       40       65
# 202  187      Hoppip    Grass  Flying   35      35       40       35       55
# 266  247     Pupitar     Rock  Ground   70      84       70       65       70
# 345  316      Gulpin   Poison     NaN   70      43       53       43       53
# 357  326     Grumpig  Psychic     NaN   80      45       65       90      110
# 358  327      Spinda   Normal     NaN   60      60       60       60       60
# ...

# %%
df.loc[df['Type 1']=='Flame','Type 1']='Grass'

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  t_stat  Generation  Legendary
# 0         65       65     45     318           1      False
# ...

# %%
df.loc[df['Sp. Atk']>100,'Legendary']=True

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  t_stat  Generation  Legendary
# 0         65       65     45     318           1      False
# ...

# %%
df=pd.read_csv('new_poke.csv')

# %%
print(df['Legendary'][796])
# Out:
# True

# %%
df.loc[df['Sp. Atk']>100, ['Legendary','Generation']]=['test1','test2']

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  t_stat Generation Legendary
# 0         65       65     45     318          1     False
# ...

# %%
df=pd.read_csv('new_poke.csv')

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  t_stat  Generation  Legendary
# 0         65       65     45     318           1      False
# ...

# %%
df.groupby(['Type 1']).sum().sort_values('Attack',ascending=False)
# Out:
#               #                                               Name  \
# Type 1
# Water     33946  SquirtleWartortleBlastoiseBlastoiseMega Blasto...
# Normal    31279  PidgeyPidgeottoPidgeotPidgeotMega PidgeotRatta...
# Grass     24141  BulbasaurIvysaurVenusaurVenusaurMega VenusaurO...
# Bug       23080  CaterpieMetapodButterfreeWeedleKakunaBeedrillB...
# Fire      17025  CharmanderCharmeleonCharizardCharizardMega Cha...
# Rock      17280  GeodudeGravelerGolemOnixOmanyteOmastarKabutoKa...
# Psychic   21706  AbraKadabraAlakazamAlakazamMega AlakazamDrowze...
# Dragon    15180  DratiniDragonairDragoniteAltariaAltariaMega Al...
# Ground    11401  SandshrewSandslashDiglettDugtrioCuboneMarowakR...
# Electric  15994  PikachuRaichuMagnemiteMagnetonVoltorbElectrode...
# Dark      14302  UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...
# Fighting   9824  MankeyPrimeapeMachopMachokeMachampHitmonleeHit...
# Steel     11957  SteelixSteelixMega SteelixSkarmoryMawileMawile...
# ...

# %%
df['count']=1

# %%
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
